# %%
from covid import Covid

# %%
instance=Covid()

# %%
data=instance.get_data()

# %%
len(data)
# Out:
# 192

# %%
print(data)
# Out:
# [{'id': '179', 'country': 'US', 'confirmed': 33056853, 'active': None, 'deaths': 588539, 'recovered': None, 'latitude': 40.0, 'longitude': -100.0, 'last_update': 1621578045000}, {'id': '80', 'country': 'India', 'confirmed': 26031991, 'active': 3027925, 'deaths': 291331, 'recovered': 22712735, 'latitude': 20.593684, 'longitude': 78.96288, 'last_update': 1621578045000}, {'id': '24', 'country': 'Brazil', 'confirmed': 15894094, 'active': 1369865, 'deaths': 444094, 'recovered': 14080135, 'latitude': -14.235, 'longitude': -51.9253, 'last_update': 1621578045000}, {'id': '63', 'country': 'France', 'confirmed': 5979099, 'active': 5137874, 'deaths': 108343, 'recovered': 382501, 'latitude': 46.2276, 'longitude': 2.2137, 'last_update': 1621578045000}, {'id': '178', 'country': 'Turkey', 'confirmed': 5160423, 'active': 125010, 'deaths': 45626, 'recovered': 4989787, 'latitude': 38.9637, 'longitude': 35.2433, 'last_update': 1621578045000}, {'id': '143', 'country': 'Russia', 'confirmed': 4917906, 'ac
# ...

# %%
instance.get_status_by_country_name("India")
# Out:
# {'id': '80',
#  'country': 'India',
#  'confirmed': 26031991,
#  'active': 3027925,
#  'deaths': 291331,
#  'recovered': 22712735,
#  'latitude': 20.593684,
#  'longitude': 78.96288,
#  'last_update': 1621578045000}
